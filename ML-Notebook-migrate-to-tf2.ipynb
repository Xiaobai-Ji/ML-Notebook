# %%
# !nvidia-smi

# %tensorflow_version 2.x
import tensorflow as tf

print(tf.__version__)
print('Available GPU: ', tf.config.list_physical_devices('GPU'))
# Out:
# Mon Feb 17 14:41:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.48.02    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    28W /  70W |   2341MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# 2.1.0
# Available GPU:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Tensorboard for Colab installation

# !pip install tensorboardcolab

from tensorboardcolab import *
tbc=TensorBoardColab()
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)
# Wait for 8 seconds...
# TensorBoard link:
# https://3891c193.ngrok.io

# %%
(x_train,y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=10000)

x_train = tf.keras.preprocessing.sequence.pad_sequences(x_train, maxlen=80)
print(x_train.shape)

embedding = tf.keras.layers.Embedding(10000,100)
out = embedding(x_train)
print(out.shape)
# Out:
# (25000, 80)
# (25000, 80, 100)

# %%
def repeater(value):
  while True:
    new = (yield value)
    if new is not None: value = new

r = repeater(42)
print(next(r))

print(r.send("Hello World"))
# Out:
# 42
# Hello World

# %%
x = tf.linspace(-8.,8,100)
y = tf.linspace(-8.,8,100)
x,y = tf.meshgrid(x,y)
print(x.shape, ' ', y.shape)

z = tf.sqrt(x**2+y**2)
z = tf.sin(z)/z

import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

ax.contour3D(x.numpy(), y.numpy(), z.numpy(), 500)
plt.show()
# Out:
# (100, 100)   (100, 100)

# %%
z = tf.random.normal([2,10])
y_onehot = tf.constant([1,3])
y_onehot = tf.one_hot(y_onehot, depth=10)

loss = tf.keras.losses.categorical_crossentropy(y_onehot, z, from_logits=True)
loss = tf.reduce_mean(loss)
print(loss)
# Out:
# tf.Tensor(2.7503502, shape=(), dtype=float32)
